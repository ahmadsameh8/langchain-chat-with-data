# %% [markdown]
# # handeled the pdf

# %%
from langchain.document_loaders import PyPDFLoader
pdf = PyPDFLoader("https://gemconsortium.org/file/open?fileId=51377")
pages = pdf.load()

# %% [markdown]
# # handeled the three links

# %%
import pandas as pd
df1 = pd.read_csv("API_IT.NET.USER.ZS_DS2_en_csv_v2_2337.csv", skiprows=4)
df2 = pd.read_csv("API_SI.POV.DDAY_DS2_en_csv_v2_3790.csv", skiprows=4)
df3 = pd.read_csv("API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_149.csv", skiprows=4)

# %% [markdown]
# # processing the data to make it sutiable documents for RAG

# %%
import pandas as pd

def replace_null_with_no_number(df, start_year, end_year):
    """
    Replace NaN values in columns from start_year to end_year with 'no number available'.

    Parameters:
    df (pd.DataFrame): The dataframe to process.
    start_year (int): The starting year.
    end_year (int): The ending year.

    Returns:
    pd.DataFrame: The updated dataframe.
    """
    for year in range(start_year, end_year + 1):
        col_name = str(year)
        if col_name in df.columns:
            df[col_name].fillna('not available', inplace=True)
    return df



# Replace NaN values for all columns from 1960 to 2023 in df1
df1 = replace_null_with_no_number(df1, 1960, 2023)
df2 = replace_null_with_no_number(df2, 1960, 2023)
df3 = replace_null_with_no_number(df3, 1960, 2023)
# Out:
# <ipython-input-6-85b976c51d49>:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_name].fillna('not available', inplace=True)
# <ipython-input-6-85b976c51d49>:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'not available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[col_name].fillna('not available', inplace=True)

# %%
import pandas as pd

def create_country_indicator_list(df, start_year, end_year, country_column, code_column, indicator_column):
    """
    Create a list of strings (Country\nCountry Code\nIndicator\nYear\nValue) for each row.

    Parameters:
    df (pd.DataFrame): The dataframe containing data.
    start_year (int): The starting year.
    end_year (int): The ending year.
    country_column (str): The column name for country.
    code_column (str): The column name for country code.
    indicator_column (str): The column name for the indicator.

    Returns:
    list: A list of strings formatted as 'Country Code\nCountry\nIndicator\nYear\nValue'.
    """
    result_list = []
    for _, row in df.iterrows():
        # Check if necessary columns exist in the current row
        if pd.notnull(row[country_column]) and pd.notnull(row[code_column]) and pd.notnull(row[indicator_column]):
            for year in range(start_year, end_year + 1):
                col_name = str(year)
                if col_name in df.columns and pd.notnull(row[col_name]):
                    result_list.append(f"{row[indicator_column]} in {row[country_column]} at {year} are {row[col_name]}")
    return result_list

# Create the string
df1_strings = create_country_indicator_list(df1, 1960, 2023, "Country Name", "Country Code", "Indicator Name")
df2_strings = create_country_indicator_list(df2, 1960, 2023, "Country Name", "Country Code", "Indicator Name")
df3_strings = create_country_indicator_list(df3, 1960, 2023, "Country Name", "Country Code", "Indicator Name")

# %%
df1_strings
# Out:
# ['Individuals using the Internet (% of population) in Aruba at 1960 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1961 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1962 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1963 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1964 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1965 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1966 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1967 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1968 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1969 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1970 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1971 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1972 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1973 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1974 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1975 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1976 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1977 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1978 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1979 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1980 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1981 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1982 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1983 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1984 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1985 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1986 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1987 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1988 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1989 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1994 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1995 are 0.0',
#  'Individuals using the Internet (% of population) in Aruba at 1996 are 2.768382663',
#  'Individuals using the Internet (% of population) in Aruba at 1997 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1998 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 1999 are 4.506179098',
#  'Individuals using the Internet (% of population) in Aruba at 2000 are 15.4428',
#  'Individuals using the Internet (% of population) in Aruba at 2001 are 17.1',
#  'Individuals using the Internet (% of population) in Aruba at 2002 are 18.8',
#  'Individuals using the Internet (% of population) in Aruba at 2003 are 20.8',
#  'Individuals using the Internet (% of population) in Aruba at 2004 are 23.0',
#  'Individuals using the Internet (% of population) in Aruba at 2005 are 25.4',
#  'Individuals using the Internet (% of population) in Aruba at 2006 are 28.0',
#  'Individuals using the Internet (% of population) in Aruba at 2007 are 30.9',
#  'Individuals using the Internet (% of population) in Aruba at 2008 are 52.0',
#  'Individuals using the Internet (% of population) in Aruba at 2009 are 58.0',
#  'Individuals using the Internet (% of population) in Aruba at 2010 are 62.0',
#  'Individuals using the Internet (% of population) in Aruba at 2011 are 69.0',
#  'Individuals using the Internet (% of population) in Aruba at 2012 are 74.0',
#  'Individuals using the Internet (% of population) in Aruba at 2013 are 78.9',
#  'Individuals using the Internet (% of population) in Aruba at 2014 are 83.78',
#  'Individuals using the Internet (% of population) in Aruba at 2015 are 88.6612',
#  'Individuals using the Internet (% of population) in Aruba at 2016 are 93.5425',
#  'Individuals using the Internet (% of population) in Aruba at 2017 are 97.17',
#  'Individuals using the Internet (% of population) in Aruba at 2018 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 2019 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 2020 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 2021 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 2022 are not available',
#  'Individuals using the Internet (% of population) in Aruba at 2023 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1960 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1961 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1962 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1963 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1964 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1965 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1966 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1967 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1968 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1969 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1970 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1971 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1972 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1973 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1974 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1975 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1976 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1977 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1978 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1979 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1980 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1981 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1982 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1983 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1984 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1985 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1986 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1987 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1988 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1989 are not available',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1991 are 0.0017323024888055',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1992 are 0.0050408083644876',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1993 are 0.0146294941425636',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1994 are 0.0317097336371475',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1995 are 0.086496310561846',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1996 are 0.112752212160974',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1997 are 0.213192402155205',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1998 are 0.386772416959473',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 1999 are 0.569512051222246',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2000 are 0.770554311763481',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2001 are 0.956731579288115',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2002 are 1.12558026821291',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2003 are 1.42155522912957',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2004 are 1.70696165554331',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2005 are 1.8',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2006 are 1.9',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2007 are 2.7',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2008 are 3.0',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2009 are 3.5',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2010 are 5.3',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2011 are 6.8',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2012 are 8.4',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2013 are 10.0',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2014 are 12.1',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2015 are 14.3',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2016 are 15.7',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2017 are 17.4',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2018 are 19.8',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2019 are 22.8',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2020 are 26.0',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2021 are 29.5',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2022 are 31.4',
#  'Individuals using the Internet (% of population) in Africa Eastern and Southern at 2023 are 34.9',
#  'Individuals using the Internet (% of population) in Afghanistan at 1960 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1961 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1962 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1963 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1964 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1965 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1966 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1967 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1968 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1969 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1970 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1971 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1972 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1973 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1974 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1975 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1976 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1977 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1978 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1979 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1980 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1981 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1982 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1983 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1984 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1985 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1986 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1987 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1988 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1989 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1994 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1995 are 0.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 1996 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1997 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1998 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 1999 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 2000 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 2001 are 0.00472257',
#  'Individuals using the Internet (% of population) in Afghanistan at 2002 are 0.0045614',
#  'Individuals using the Internet (% of population) in Afghanistan at 2003 are 0.0878913',
#  'Individuals using the Internet (% of population) in Afghanistan at 2004 are 0.105809',
#  'Individuals using the Internet (% of population) in Afghanistan at 2005 are 1.22415',
#  'Individuals using the Internet (% of population) in Afghanistan at 2006 are 2.10712',
#  'Individuals using the Internet (% of population) in Afghanistan at 2007 are 1.9',
#  'Individuals using the Internet (% of population) in Afghanistan at 2008 are 1.84',
#  'Individuals using the Internet (% of population) in Afghanistan at 2009 are 3.55',
#  'Individuals using the Internet (% of population) in Afghanistan at 2010 are 4.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 2011 are 5.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 2012 are 5.45455',
#  'Individuals using the Internet (% of population) in Afghanistan at 2013 are 5.9',
#  'Individuals using the Internet (% of population) in Afghanistan at 2014 are 7.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 2015 are 8.26',
#  'Individuals using the Internet (% of population) in Afghanistan at 2016 are 11.0',
#  'Individuals using the Internet (% of population) in Afghanistan at 2017 are 13.5',
#  'Individuals using the Internet (% of population) in Afghanistan at 2018 are 16.8',
#  'Individuals using the Internet (% of population) in Afghanistan at 2019 are 17.6',
#  'Individuals using the Internet (% of population) in Afghanistan at 2020 are 18.4',
#  'Individuals using the Internet (% of population) in Afghanistan at 2021 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 2022 are not available',
#  'Individuals using the Internet (% of population) in Afghanistan at 2023 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1960 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1961 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1962 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1963 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1964 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1965 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1966 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1967 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1968 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1969 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1970 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1971 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1972 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1973 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1974 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1975 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1976 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1977 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1978 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1979 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1980 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1981 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1982 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1983 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1984 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1985 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1986 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1987 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1988 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1989 are not available',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1994 are 4.37347303003985e-06',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1995 are 0.0001329378087813',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1996 are 0.0070178877270851',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1997 are 0.0199454592058786',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1998 are 0.0356483338548163',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 1999 are 0.0865832729233697',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2000 are 0.139392839690942',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2001 are 0.210108428653952',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2002 are 0.412177044564681',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2003 are 0.658125887693842',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2004 are 1.17857855933007',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2005 are 2.3',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2006 are 3.4',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2007 are 4.2',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2008 are 5.0',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2009 are 5.8',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2010 are 7.2',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2011 are 8.7',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2012 are 10.3',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2013 are 12.6',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2014 are 14.9',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2015 are 17.2',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2016 are 19.9',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2017 are 23.2',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2018 are 25.7',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2019 are 28.9',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2020 are 32.4',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2021 are 34.3',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2022 are 36.9',
#  'Individuals using the Internet (% of population) in Africa Western and Central at 2023 are 39.4',
#  'Individuals using the Internet (% of population) in Angola at 1960 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1961 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1962 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1963 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1964 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1965 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1966 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1967 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1968 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1969 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1970 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1971 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1972 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1973 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1974 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1975 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1976 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1977 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1978 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1979 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1980 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1981 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1982 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1983 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1984 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1985 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1986 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1987 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1988 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1989 are not available',
#  'Individuals using the Internet (% of population) in Angola at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1994 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1995 are 0.0',
#  'Individuals using the Internet (% of population) in Angola at 1996 are 0.000775929',
#  'Individuals using the Internet (% of population) in Angola at 1997 are 0.005673746',
#  'Individuals using the Internet (% of population) in Angola at 1998 are 0.018453724',
#  'Individuals using the Internet (% of population) in Angola at 1999 are 0.071964087',
#  'Individuals using the Internet (% of population) in Angola at 2000 are 0.105046',
#  'Individuals using the Internet (% of population) in Angola at 2001 are 0.136014',
#  'Individuals using the Internet (% of population) in Angola at 2002 are 0.270377',
#  'Individuals using the Internet (% of population) in Angola at 2003 are 0.370682',
#  'Individuals using the Internet (% of population) in Angola at 2004 are 0.464815',
#  'Individuals using the Internet (% of population) in Angola at 2005 are 1.14337',
#  'Individuals using the Internet (% of population) in Angola at 2006 are 1.5',
#  'Individuals using the Internet (% of population) in Angola at 2007 are 1.7',
#  'Individuals using the Internet (% of population) in Angola at 2008 are 1.9',
#  'Individuals using the Internet (% of population) in Angola at 2009 are 2.3',
#  'Individuals using the Internet (% of population) in Angola at 2010 are 2.8',
#  'Individuals using the Internet (% of population) in Angola at 2011 are 4.7',
#  'Individuals using the Internet (% of population) in Angola at 2012 are 7.7',
#  'Individuals using the Internet (% of population) in Angola at 2013 are 13.0',
#  'Individuals using the Internet (% of population) in Angola at 2014 are 21.3623',
#  'Individuals using the Internet (% of population) in Angola at 2015 are 22.0',
#  'Individuals using the Internet (% of population) in Angola at 2016 are 23.2',
#  'Individuals using the Internet (% of population) in Angola at 2017 are 26.0',
#  'Individuals using the Internet (% of population) in Angola at 2018 are 29.0',
#  'Individuals using the Internet (% of population) in Angola at 2019 are 32.1294',
#  'Individuals using the Internet (% of population) in Angola at 2020 are 36.6347',
#  'Individuals using the Internet (% of population) in Angola at 2021 are 37.8067',
#  'Individuals using the Internet (% of population) in Angola at 2022 are 39.2935',
#  'Individuals using the Internet (% of population) in Angola at 2023 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1960 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1961 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1962 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1963 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1964 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1965 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1966 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1967 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1968 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1969 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1970 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1971 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1972 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1973 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1974 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1975 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1976 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1977 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1978 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1979 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1980 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1981 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1982 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1983 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1984 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1985 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1986 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1987 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1988 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1989 are not available',
#  'Individuals using the Internet (% of population) in Albania at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Albania at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Albania at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Albania at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Albania at 1994 are 0.0',
#  'Individuals using the Internet (% of population) in Albania at 1995 are 0.011168695',
#  'Individuals using the Internet (% of population) in Albania at 1996 are 0.032196828',
#  'Individuals using the Internet (% of population) in Albania at 1997 are 0.048593919',
#  'Individuals using the Internet (% of population) in Albania at 1998 are 0.06502737',
#  'Individuals using the Internet (% of population) in Albania at 1999 are 0.081437045',
#  'Individuals using the Internet (% of population) in Albania at 2000 are 0.114097',
#  'Individuals using the Internet (% of population) in Albania at 2001 are 0.325798',
#  'Individuals using the Internet (% of population) in Albania at 2002 are 0.390081',
#  'Individuals using the Internet (% of population) in Albania at 2003 are 0.9719',
#  'Individuals using the Internet (% of population) in Albania at 2004 are 2.42039',
#  'Individuals using the Internet (% of population) in Albania at 2005 are 6.04389',
#  'Individuals using the Internet (% of population) in Albania at 2006 are 9.60999',
#  'Individuals using the Internet (% of population) in Albania at 2007 are 15.0361',
#  'Individuals using the Internet (% of population) in Albania at 2008 are 23.86',
#  'Individuals using the Internet (% of population) in Albania at 2009 are 41.2',
#  'Individuals using the Internet (% of population) in Albania at 2010 are 45.0',
#  'Individuals using the Internet (% of population) in Albania at 2011 are 47.0',
#  'Individuals using the Internet (% of population) in Albania at 2012 are 49.4',
#  'Individuals using the Internet (% of population) in Albania at 2013 are 51.8',
#  'Individuals using the Internet (% of population) in Albania at 2014 are 54.3',
#  'Individuals using the Internet (% of population) in Albania at 2015 are 56.9',
#  'Individuals using the Internet (% of population) in Albania at 2016 are 59.6',
#  'Individuals using the Internet (% of population) in Albania at 2017 are 62.4',
#  'Individuals using the Internet (% of population) in Albania at 2018 are 65.4',
#  'Individuals using the Internet (% of population) in Albania at 2019 are 68.5504',
#  'Individuals using the Internet (% of population) in Albania at 2020 are 72.2377',
#  'Individuals using the Internet (% of population) in Albania at 2021 are 79.3237',
#  'Individuals using the Internet (% of population) in Albania at 2022 are 82.6137',
#  'Individuals using the Internet (% of population) in Albania at 2023 are 83.1356',
#  'Individuals using the Internet (% of population) in Andorra at 1960 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1961 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1962 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1963 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1964 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1965 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1966 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1967 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1968 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1969 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1970 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1971 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1972 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1973 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1974 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1975 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1976 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1977 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1978 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1979 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1980 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1981 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1982 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1983 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1984 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1985 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1986 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1987 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1988 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1989 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1994 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1995 are 0.0',
#  'Individuals using the Internet (% of population) in Andorra at 1996 are 1.526601023',
#  'Individuals using the Internet (% of population) in Andorra at 1997 are 3.050175385',
#  'Individuals using the Internet (% of population) in Andorra at 1998 are 6.886209218',
#  'Individuals using the Internet (% of population) in Andorra at 1999 are 7.635686143',
#  'Individuals using the Internet (% of population) in Andorra at 2000 are 10.5388',
#  'Individuals using the Internet (% of population) in Andorra at 2001 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 2002 are 11.2605',
#  'Individuals using the Internet (% of population) in Andorra at 2003 are 13.5464',
#  'Individuals using the Internet (% of population) in Andorra at 2004 are 26.838',
#  'Individuals using the Internet (% of population) in Andorra at 2005 are 37.6058',
#  'Individuals using the Internet (% of population) in Andorra at 2006 are 48.9368',
#  'Individuals using the Internet (% of population) in Andorra at 2007 are 70.87',
#  'Individuals using the Internet (% of population) in Andorra at 2008 are 70.04',
#  'Individuals using the Internet (% of population) in Andorra at 2009 are 78.53',
#  'Individuals using the Internet (% of population) in Andorra at 2010 are 81.0',
#  'Individuals using the Internet (% of population) in Andorra at 2011 are 81.0',
#  'Individuals using the Internet (% of population) in Andorra at 2012 are 82.7',
#  'Individuals using the Internet (% of population) in Andorra at 2013 are 84.4',
#  'Individuals using the Internet (% of population) in Andorra at 2014 are 86.1',
#  'Individuals using the Internet (% of population) in Andorra at 2015 are 87.9',
#  'Individuals using the Internet (% of population) in Andorra at 2016 are 89.7',
#  'Individuals using the Internet (% of population) in Andorra at 2017 are 91.5675',
#  'Individuals using the Internet (% of population) in Andorra at 2018 are not available',
#  'Individuals using the Internet (% of population) in Andorra at 2019 are 90.7187',
#  'Individuals using the Internet (% of population) in Andorra at 2020 are 93.2056',
#  'Individuals using the Internet (% of population) in Andorra at 2021 are 93.8975',
#  'Individuals using the Internet (% of population) in Andorra at 2022 are 94.4855',
#  'Individuals using the Internet (% of population) in Andorra at 2023 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1960 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1961 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1962 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1963 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1964 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1965 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1966 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1967 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1968 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1969 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1970 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1971 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1972 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1973 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1974 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1975 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1976 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1977 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1978 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1979 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1980 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1981 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1982 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1983 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1984 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1985 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1986 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1987 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1988 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1989 are not available',
#  'Individuals using the Internet (% of population) in Arab World at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Arab World at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Arab World at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Arab World at 1993 are 0.0008646341972295',
#  'Individuals using the Internet (% of population) in Arab World at 1994 are 0.0028776014345114',
#  'Individuals using the Internet (% of population) in Arab World at 1995 are 0.0146856685731192',
#  'Individuals using the Internet (% of population) in Arab World at 1996 are 0.0402727667612479',
#  'Individuals using the Internet (% of population) in Arab World at 1997 are 0.141948279814273',
#  'Individuals using the Internet (% of population) in Arab World at 1998 are 0.283811604320554',
#  'Individuals using the Internet (% of population) in Arab World at 1999 are 0.644800202411028',
#  'Individuals using the Internet (% of population) in Arab World at 2000 are 1.19958727732213',
#  'Individuals using the Internet (% of population) in Arab World at 2001 are 1.59120989847399',
#  'Individuals using the Internet (% of population) in Arab World at 2002 are 2.75053067066617',
#  'Individuals using the Internet (% of population) in Arab World at 2003 are 3.72017869649154',
#  'Individuals using the Internet (% of population) in Arab World at 2004 are 7.21464387242599',
#  'Individuals using the Internet (% of population) in Arab World at 2005 are 8.56024842258593',
#  'Individuals using the Internet (% of population) in Arab World at 2006 are 11.4647639274414',
#  'Individuals using the Internet (% of population) in Arab World at 2007 are 14.0777895228414',
#  'Individuals using the Internet (% of population) in Arab World at 2008 are 18.1551283495199',
#  'Individuals using the Internet (% of population) in Arab World at 2009 are 21.0329148154073',
#  'Individuals using the Internet (% of population) in Arab World at 2010 are 25.1765059118961',
#  'Individuals using the Internet (% of population) in Arab World at 2011 are 27.0087789454644',
#  'Individuals using the Internet (% of population) in Arab World at 2012 are 30.2417200504835',
#  'Individuals using the Internet (% of population) in Arab World at 2013 are 33.3623625275877',
#  'Individuals using the Internet (% of population) in Arab World at 2014 are 37.0277926842634',
#  'Individuals using the Internet (% of population) in Arab World at 2015 are 40.9823815703012',
#  'Individuals using the Internet (% of population) in Arab World at 2016 are 41.0700134985783',
#  'Individuals using the Internet (% of population) in Arab World at 2017 are 48.1918379605552',
#  'Individuals using the Internet (% of population) in Arab World at 2018 are 52.5173038249928',
#  'Individuals using the Internet (% of population) in Arab World at 2019 are 60.0783092421506',
#  'Individuals using the Internet (% of population) in Arab World at 2020 are 60.2643027640711',
#  'Individuals using the Internet (% of population) in Arab World at 2021 are 64.1684287501043',
#  'Individuals using the Internet (% of population) in Arab World at 2022 are 67.356409919213',
#  'Individuals using the Internet (% of population) in Arab World at 2023 are not available',
#  'Individuals using the Internet (% of population) in United Arab Emirates at 1960 are not available',
#  'Individuals using the Internet (% of population) in United Arab Emirates at 1961 are not available',
#  'Individuals using the Internet (% of population) in United Arab Emirates at 1962 are not available',
#  'Individuals using the Internet (% of population) in United Arab Emirates at 1963 are not available',
#  'Individuals using the Internet (% of population) in United Arab Emirates at 1964 are not available',
# ...
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2014 are 67.78',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2015 are 70.0',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2016 are 73.0',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2017 are 76.2',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2018 are 79.6',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2019 are 83.2',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2020 are 86.8837',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2021 are 87.074',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2022 are 91.4123',
#  'Individuals using the Internet (% of population) in Antigua and Barbuda at 2023 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1960 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1961 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1962 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1963 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1964 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1965 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1966 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1967 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1968 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1969 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1970 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1971 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1972 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1973 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1974 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1975 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1976 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1977 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1978 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1979 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1980 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1981 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1982 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1983 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1984 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1985 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1986 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1987 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1988 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1989 are not available',
#  'Individuals using the Internet (% of population) in Australia at 1990 are 0.585094712',
#  'Individuals using the Internet (% of population) in Australia at 1991 are 1.097203891',
#  'Individuals using the Internet (% of population) in Australia at 1992 are 1.768764913',
#  'Individuals using the Internet (% of population) in Australia at 1993 are 1.974611016',
#  'Individuals using the Internet (% of population) in Australia at 1994 are 2.232101254',
#  'Individuals using the Internet (% of population) in Australia at 1995 are 2.759654513',
#  'Individuals using the Internet (% of population) in Australia at 1996 are 3.27524987',
#  'Individuals using the Internet (% of population) in Australia at 1997 are 16.36935838',
#  'Individuals using the Internet (% of population) in Australia at 1998 are 30.81323944',
#  'Individuals using the Internet (% of population) in Australia at 1999 are 40.7837839',
#  'Individuals using the Internet (% of population) in Australia at 2000 are 46.7561',
#  'Individuals using the Internet (% of population) in Australia at 2001 are 52.6893',
#  'Individuals using the Internet (% of population) in Australia at 2002 are not available',
#  'Individuals using the Internet (% of population) in Australia at 2003 are not available',
#  'Individuals using the Internet (% of population) in Australia at 2004 are not available',
#  'Individuals using the Internet (% of population) in Australia at 2005 are 63.0',
#  'Individuals using the Internet (% of population) in Australia at 2006 are 66.0',
#  'Individuals using the Internet (% of population) in Australia at 2007 are 69.45',
#  'Individuals using the Internet (% of population) in Australia at 2008 are 71.67',
#  'Individuals using the Internet (% of population) in Australia at 2009 are 74.25',
#  'Individuals using the Internet (% of population) in Australia at 2010 are 76.0',
#  'Individuals using the Internet (% of population) in Australia at 2011 are 79.4877',
#  'Individuals using the Internet (% of population) in Australia at 2012 are 79.0',
#  'Individuals using the Internet (% of population) in Australia at 2013 are 83.4535',
#  'Individuals using the Internet (% of population) in Australia at 2014 are 84.0',
#  'Individuals using the Internet (% of population) in Australia at 2015 are 84.5605',
#  'Individuals using the Internet (% of population) in Australia at 2016 are 86.54',
#  'Individuals using the Internet (% of population) in Australia at 2017 are 86.545',
#  'Individuals using the Internet (% of population) in Australia at 2018 are 90.0',
#  'Individuals using the Internet (% of population) in Australia at 2019 are 93.6099',
#  'Individuals using the Internet (% of population) in Australia at 2020 are 94.6935',
#  'Individuals using the Internet (% of population) in Australia at 2021 are 94.9886',
#  'Individuals using the Internet (% of population) in Australia at 2022 are 94.8762',
#  'Individuals using the Internet (% of population) in Australia at 2023 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1960 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1961 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1962 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1963 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1964 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1965 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1966 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1967 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1968 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1969 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1970 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1971 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1972 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1973 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1974 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1975 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1976 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1977 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1978 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1979 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1980 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1981 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1982 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1983 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1984 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1985 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1986 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1987 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1988 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1989 are not available',
#  'Individuals using the Internet (% of population) in Austria at 1990 are 0.130369377',
#  'Individuals using the Internet (% of population) in Austria at 1991 are 0.259081553',
#  'Individuals using the Internet (% of population) in Austria at 1992 are 0.642817619',
#  'Individuals using the Internet (% of population) in Austria at 1993 are 0.76534273',
#  'Individuals using the Internet (% of population) in Austria at 1994 are 1.393422968',
#  'Individuals using the Internet (% of population) in Austria at 1995 are 1.890210524',
#  'Individuals using the Internet (% of population) in Austria at 1996 are 6.909162353',
#  'Individuals using the Internet (% of population) in Austria at 1997 are 9.533974317',
#  'Individuals using the Internet (% of population) in Austria at 1998 are 15.42121932',
#  'Individuals using the Internet (% of population) in Austria at 1999 are 23.0443171',
#  'Individuals using the Internet (% of population) in Austria at 2000 are 33.7301',
#  'Individuals using the Internet (% of population) in Austria at 2001 are 39.1855',
#  'Individuals using the Internet (% of population) in Austria at 2002 are 36.56',
#  'Individuals using the Internet (% of population) in Austria at 2003 are 42.7',
#  'Individuals using the Internet (% of population) in Austria at 2004 are 54.28',
#  'Individuals using the Internet (% of population) in Austria at 2005 are 58.0',
#  'Individuals using the Internet (% of population) in Austria at 2006 are 63.6',
#  'Individuals using the Internet (% of population) in Austria at 2007 are 69.37',
#  'Individuals using the Internet (% of population) in Austria at 2008 are 72.87',
#  'Individuals using the Internet (% of population) in Austria at 2009 are 73.45',
#  'Individuals using the Internet (% of population) in Austria at 2010 are 75.17',
#  'Individuals using the Internet (% of population) in Austria at 2011 are 78.74',
#  'Individuals using the Internet (% of population) in Austria at 2012 are 80.03',
#  'Individuals using the Internet (% of population) in Austria at 2013 are 80.6188',
#  'Individuals using the Internet (% of population) in Austria at 2014 are 80.9958',
#  'Individuals using the Internet (% of population) in Austria at 2015 are 83.9401',
#  'Individuals using the Internet (% of population) in Austria at 2016 are 84.3237',
#  'Individuals using the Internet (% of population) in Austria at 2017 are 87.9356',
#  'Individuals using the Internet (% of population) in Austria at 2018 are 87.4791',
#  'Individuals using the Internet (% of population) in Austria at 2019 are 87.7522',
#  'Individuals using the Internet (% of population) in Austria at 2020 are 87.5294',
#  'Individuals using the Internet (% of population) in Austria at 2021 are 92.5292',
#  'Individuals using the Internet (% of population) in Austria at 2022 are 93.6141',
#  'Individuals using the Internet (% of population) in Austria at 2023 are 95.3347',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1960 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1961 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1962 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1963 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1964 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1965 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1966 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1967 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1968 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1969 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1970 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1971 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1972 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1973 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1974 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1975 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1976 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1977 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1978 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1979 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1980 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1981 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1982 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1983 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1984 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1985 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1986 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1987 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1988 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1989 are not available',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1990 are 0.0',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1991 are 0.0',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1992 are 0.0',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1993 are 0.0',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1994 are 0.001431415',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1995 are 0.002055556',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1996 are 0.006354585',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1997 are 0.025187933',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1998 are 0.037485109',
#  'Individuals using the Internet (% of population) in Azerbaijan at 1999 are 0.099228942',
#  ...]

# %%
from langchain_core.documents import Document

def convert_to_documents(strings_list):
    """
    Convert a list of strings into a list of Document objects.

    Parameters:
    strings_list (List[str]): A list of strings.

    Returns:
    List[Document]: A list of Document objects.
    """
    return [Document(page_content=s) for s in strings_list]

# %%
df1_docs = convert_to_documents(df1_strings)
df2_docs = convert_to_documents(df2_strings)
df3_docs = convert_to_documents(df3_strings)

# %% [markdown]
# # adding the datasets together with the pdf

# %%
docs_all = df1_docs + df2_docs + df3_docs + pages

# %% [markdown]
# # loading the default Embeddings model

# %%
from langchain_huggingface import HuggingFaceEmbeddings

hf = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # creating the vector database with documents and Embeddings model

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma/'

# %%
# !rm -rf ./docs/chroma  # remove old database files if any
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
vectordb = Chroma.from_documents(
    documents=docs_all,
    embedding=hf,
    persist_directory=persist_directory
)

# %% [markdown]
# # testing the retrival

# %%
question = "what is Individuals using the Internet (% of population) in Azerbaijan at 1998?"
docs = vectordb.similarity_search(question,k=1)

# %%
print(docs[0].page_content)
# Out:
# Individuals using the Internet (% of population) in Azerbaijan at 1998 are 0.037485109

# %% [markdown]
# # trying the language model and chatbot memory

# %%
from langchain_huggingface import HuggingFacePipeline
llm = HuggingFacePipeline.from_model_id(
    model_id="tiiuae/Falcon3-1B-Instruct",
    task="text-generation",
    pipeline_kwargs={"max_new_tokens": 1000},
    device = 0
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/364k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.78M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/656 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.34G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/113 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

persist_directory = 'docs/chroma/'
embedding = HuggingFaceEmbeddings()
vectordb = Chroma(persist_directory=persist_directory, embedding_function=embedding)
# Out:
# <ipython-input-21-b6d1f861b8fa>:6: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectordb = Chroma(persist_directory=persist_directory, embedding_function=embedding)

# %%
from langchain.memory import ConversationBufferMemory
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)
# Out:
# <ipython-input-26-865cacf70752>:2: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(

# %%
from langchain.chains import ConversationalRetrievalChain
retriever=vectordb.as_retriever(search_kwargs={"k":1})
qa = ConversationalRetrievalChain.from_llm(
    llm,
    retriever=retriever,
    memory=memory,
)

# %%
question = "what is Individuals using the Internet (% of population) in Azerbaijan at 1998?"

# %%
result = qa({"question": question})

# %%
result['answer']

# %%
output = result["answer"]
answer = output.split("Helpful Answer:")[-1].strip()

# %%
answer
# Out:
# "Yes, I'm sure of that."
